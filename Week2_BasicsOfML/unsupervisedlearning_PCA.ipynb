# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
wines = datasets.load_wine()
X = wines.data
Y = wines.target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
X, Y,
test_size = 0.2, 
random_state = 1,
shuffle = True, 
stratify = Y )

# %%
ss = StandardScaler()
X_train_std = ss.fit_transform(X_train)
X_test_std = ss.fit_transform(X_test)

# %%
P_model = PCA(n_components=2)  
P_model.fit(X_train_std) 
X_test_PCA = P_model.transform(X_test_std)
print("降维前：", X_test_std[: 3], sep="\n")
print("降维后：", X_test_PCA[: 3], sep="\n")
# Out:
# 降维前：
# [[-0.56174327 -0.27354334 -0.45152384  0.00651661 -1.01873916 -0.29828219
#    0.44303545 -0.72992281  0.40219259 -0.57098958  0.853762    0.79217393
#   -0.15183584]
#  [-1.00971576 -0.98310465 -0.87372794 -0.09402536 -0.83851995  1.83641202
#    1.74024324 -0.92385064  0.71245545 -0.32167939  0.35602221  0.24459963
#   -0.32784591]
#  [ 0.20620956  1.09763594  0.30844355  0.91139433 -0.47808152 -0.73492418
#   -1.43897913  1.11239158 -0.49412233  1.30714719 -1.67641525 -1.45732048
#   -0.36044036]]
# 降维后：
# [[ 0.77590259 -1.51097125]
#  [ 2.07637468 -1.52794485]
#  [-3.13134976  1.61294134]]

# %%
plt.scatter(X_test_PCA[:,0], X_test_PCA[:,1])
plt.show()
